# %% [markdown]
# ### Student Name:

# %%
import pandas as pd

# %%
#load the data into a dataframe
data = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/bad-drivers/bad-drivers.csv')

#view samples of the data
data.head()
# Out:
#         State  \
# 0     Alabama
# 1      Alaska
# 2     Arizona
# 3    Arkansas
# 4  California
#
#    Number of drivers involved in fatal collisions per billion miles  \
# 0                                               18.8
# 1                                               18.1
# 2                                               18.6
# 3                                               22.4
# 4                                               12.0
#
#    Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# 0                                                 39
# 1                                                 41
# 2                                                 35
# 3                                                 18
# 4                                                 35
#
#    Percentage Of Drivers Involved In Fatal Collisions Who Were Alcohol-Impaired  \
# 0                                                 30
# 1                                                 25
# ...

# %%
data.describe()
# Out:
#        Number of drivers involved in fatal collisions per billion miles  \
# count                                          51.000000
# mean                                           15.790196
# std                                             4.122002
# min                                             5.900000
# 25%                                            12.750000
# 50%                                            15.600000
# 75%                                            18.500000
# max                                            23.900000
#
#        Percentage Of Drivers Involved In Fatal Collisions Who Were Speeding  \
# count                                          51.000000
# mean                                           31.725490
# std                                             9.633438
# min                                            13.000000
# 25%                                            23.000000
# 50%                                            34.000000
# ...

# %% [markdown]
# ## Visualize the correlations

# %%
#TODO:

# %% [markdown]
# ## Visualize the distribution of the data.
# Is the data skewed and do you detect any outliers? Note: you do not need to remove any outliers

# %%
#TODO:

# %% [markdown]
# ## Scale the data

# %%
#TODO:

# %% [markdown]
# ## Cluster the data
# Use an appropriate algorithm to cluster the data. Start with two features -- use your intuition about the features based on the analysis above and incrementally add more features (as necessary) to support your analysis. Explain the challenges you encounter as the dimensions of the data increase and if this affects your ability to detect clusters and identify patterns in the data.
#
# Note: you can optionally implement a dimensionality reduction technique like PCA (if necessary).

# %%
#TODO:

# %% [markdown]
# ## Summary
# Summarize the results and include any additional visualizations (if necessary). How many clusters did you identify and what states are the outliers?
